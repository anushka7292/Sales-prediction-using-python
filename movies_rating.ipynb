# %% [markdown]
# IMPORTING IMPORTANT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline
import sklearn
import scipy.stats as stats
import seaborn as sns
import plotly.express as px

from sklearn.model_selection import train_test_split, cross_val_score

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import accuracy_score, mean_absolute_error, mean_squared_error, r2_score
import warnings
warnings.filterwarnings('ignore')
plt.rcParams["figure.figsize"] = [10,5]

import warnings
warnings.simplefilter(action = "ignore", category = FutureWarning)

# %% [markdown]
# DOWNLOADING  DATASETS

# %%
df_movies = pd.read_csv('/content/IMDb Movies India.csv', sep="::",engine='python', encoding='latin 1')
df_movies.dropna(inplace=True)
df_movies.head(20)
# Out:
#    Name,Year,Duration,Genre,Rating,Votes,Director,Actor 1,Actor 2,Actor 3
# 0   ,,,Drama,,,J.S. Randhawa,Manmauji,Birbal,Rajen...
# 1   #Gadhvi (He thought he was Gandhi),(2019),109 ...
# 2   #Homecoming,(2021),90 min,"Drama, Musical",,,S...
# 3   #Yaaram,(2019),110 min,"Comedy, Romance",4.4,3...
# 4   ...And Once Again,(2010),105 min,Drama,,,Amol ...
# 5   ...Aur Pyaar Ho Gaya,(1997),147 min,"Comedy, D...
# 6   ...Yahaan,(2005),142 min,"Drama, Romance, War"...
# 7   .in for Motion,(2008),59 min,Documentary,,,Ani...
# 8   ?: A Question Mark,(2012),82 min,"Horror, Myst...
# 9   @Andheri,(2014),116 min,"Action, Crime, Thrill...
# 10  1:1.6 An Ode to Lost Love,(2004),96 min,Drama,...
# 11  1:13:7 Ek Tera Saath,(2016),120 min,Horror,5.9...
# 12  100 Days,(1991),161 min,"Horror, Romance, Thri...
# 13  100% Love,(2012),166 min,"Comedy, Drama, Roman...
# 14  101 Ratein,(1990),,Thriller,,,Harish,Saraswati...
# 15  102 Not Out,(2018),102 min,"Comedy, Drama",7.4...
# 16  108 Limited,,,,,,Anand Anddy,Vijay Raaz,Sanjay...
# 17  108 Teerthyatra,(1987),,"Comedy, Drama, Fantas...
# 18  10ml LOVE,(2010),87 min,"Comedy, Drama, Romanc...
# 19  11 O'Clock,(1948),,,,,Homi Wadia,Aftab,Sayani ...

# %%
df_movies.shape
# Out:
# (15509, 1)

# %%
df_movies.describe()
# Out:
#        Name,Year,Duration,Genre,Rating,Votes,Director,Actor 1,Actor 2,Actor 3
# count                                               15509
# unique                                              15503
# top     Shivani,(2019),,Crime,,,Ugresh Prasad Ujala,Sa...
# freq                                                    2

# %%
df_movies.isna().sum()
# Out:
# Name,Year,Duration,Genre,Rating,Votes,Director,Actor 1,Actor 2,Actor 3    0
# dtype: int64

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 1 columns):
#  #   Column                                                                  Non-Null Count  Dtype
# ---  ------                                                                  --------------  -----
#  0   Name,Year,Duration,Genre,Rating,Votes,Director,Actor 1,Actor 2,Actor 3  15509 non-null  object
# dtypes: object(1)
# memory usage: 121.3+ KB

# %%
nulls = df_movies[df_movies.iloc[:, 1:9].isna().all(axis=1)]
nulls.head()
# Out:
#   Name,Year,Duration,Genre,Rating,Votes,Director,Actor 1,Actor 2,Actor 3
# 0  ,,,Drama,,,J.S. Randhawa,Manmauji,Birbal,Rajen...
# 1  #Gadhvi (He thought he was Gandhi),(2019),109 ...
# 2  #Homecoming,(2021),90 min,"Drama, Musical",,,S...
# 3  #Yaaram,(2019),110 min,"Comedy, Romance",4.4,3...
# 4  ...And Once Again,(2010),105 min,Drama,,,Amol ...

# %%
for col in df_movies.select_dtypes(include = "object"):
    print(f"Name of Column: {col}")
    print(df_movies[col].unique())
    print('\n', '-'*60, '\n')
# Out:
# Name of Column: Name,Year,Duration,Genre,Rating,Votes,Director,Actor 1,Actor 2,Actor 3
# [',,,Drama,,,J.S. Randhawa,Manmauji,Birbal,Rajendra Bhatia'
#  '#Gadhvi (He thought he was Gandhi),(2019),109 min,Drama,7.0,8,Gaurav Bakshi,Rasika Dugal,Vivek Ghamande,Arvind Jangid'
#  '#Homecoming,(2021),90 min,"Drama, Musical",,,Soumyajit Majumdar,Sayani Gupta,Plabita Borthakur,Roy Angana'
#  ... 'Zulmi Raj,(2005),,Action,,,Kiran Thej,Sangeeta Tiwari,,'
#  'Zulmi Shikari,(1988),,Action,,,,,,'
#  'Zulm-O-Sitam,(1998),130 min,"Action, Drama",6.2,20,K.C. Bokadia,Dharmendra,Jaya Prada,Arjun Sarja']
#
#  ------------------------------------------------------------

# %%
df_movies.rename(columns={
    'votes': 'Votes',
}, inplace=True)

# %%
print(df_movies.columns)
# Out:
# Index(['Name,Year,Duration,Genre,Rating,Votes,Director,Actor 1,Actor 2,Actor 3'], dtype='object')

# %%
# Find the row with the highest number of votes
max_votes_row = df_movies[df_movies['Votes'] == df_movies['Votes'].max()]

# Get the name of the movie with the highest votes
movie_highest_votes = max_votes_row['Name'].values[0]

# Find the number of votes for the movie with the highest votes
votes_highest_votes = max_votes_row['Votes'].values[0]

print("Movie with the highest votes:", movie_highest_votes)
print("Number of votes for the movie with the highest votes:", votes_highest_votes)
print('\n', '='*100, '\n')


# Find the row with the lowest number of votes
min_votes_row = df_movies[df_movies['Votes'] == df_movies['Votes'].min()]

# Get the name of the movie with the lowest votes
movie_lowest_votes = min_votes_row['Name'].values[0]

# Find the number of votes for the movie with the lowest votes
votes_lowest_votes = min_votes_row['Votes'].values[0]

print("Movie with the highest votes:", movie_lowest_votes)
print("Number of votes for the movie with the highest votes:", votes_lowest_votes)
